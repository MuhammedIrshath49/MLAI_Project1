# %%
import pandas as pd #data processing
import numpy as np #arithmetic operation

from IPython.display import display

quality = pd.read_csv("RED WINE QUALITY DATASET.csv")
pd.options.display.max_columns = None
display(quality)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.4             0.700         0.00             1.9      0.076
# 1              7.8             0.880         0.00             2.6      0.098
# 2              7.8             0.760         0.04             2.3      0.092
# 3             11.2             0.280         0.56             1.9      0.075
# 4              7.4             0.700         0.00             1.9      0.076
# ..             ...               ...          ...             ...        ...
# 194            7.6             0.550         0.21             2.2      0.071
# 195            7.8             0.590         0.33             2.0      0.074
# 196            7.3             0.580         0.30             2.4      0.074
# 197           11.5             0.300         0.60             2.0      0.067
# 198            5.4             0.835         0.08             1.2      0.046
#
# ...
